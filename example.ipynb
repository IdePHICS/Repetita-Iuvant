# %%
# %%capture
import running

running.run_path('hyperparameters/example/', read_all=True, recursive=True);

# %% [markdown]
# ## Multi-index $k=3, k^\star=1$

# %%
import plotting

plotting.plot_from_hyperparams(
    'hyperparameters/example/k3_kstar1.yaml',
    save_flag=True,
    show_flag=True,
    latex_flag=True # requires latex to be installed
)
# Out:
# Plotting algo = true_sam -- d = 204
# 100%|██████████| 40/40 [00:00<00:00, 311.43it/s]
# Plotting algo = true_sam -- d = 409
# 100%|██████████| 40/40 [00:00<00:00, 175.88it/s]
# Plotting algo = true_sam -- d = 819
# 100%|██████████| 40/40 [00:00<00:00, 85.68it/s]
# Plotting algo = gd -- d = 204
# 100%|██████████| 40/40 [00:00<00:00, 283.84it/s]
# Plotting algo = gd -- d = 409
# 100%|██████████| 40/40 [00:00<00:00, 166.24it/s]
# Plotting algo = gd -- d = 819
# 100%|██████████| 40/40 [00:00<00:00, 78.82it/s]
